# %%
# %pip install pandas numpy seaborn matplotlib scipy

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore

df = pd.read_csv("../data/benin-malanville.csv", parse_dates=["Timestamp"])
# Out:
# Requirement already satisfied: pandas in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (2.2.5)
# Requirement already satisfied: seaborn in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: scipy in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\rebika\solar-challenge-week1\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.describe()
df.isna().sum()

# List columns with >5% missing
missing_report = df.isna().mean() * 100
missing_report[missing_report > 5]
# Out:
# Comments    100.0
# dtype: float64

# %%
columns_to_check = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']
df['outlier_flag'] = 0

for col in columns_to_check:
    df[f"{col}_zscore"] = zscore(df[col].fillna(df[col].median()))
    df['outlier_flag'] |= df[f"{col}_zscore"].abs() > 3

# Drop or Impute
df_clean = df.copy()
for col in columns_to_check:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# %%
df_clean.to_csv("../data/benin_clean.csv", index=False)

# %%
df_clean.set_index("Timestamp")[["GHI", "DNI", "DHI", "Tamb"]].plot(figsize=(14, 5))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df_clean['Month'] = df_clean['Timestamp'].dt.month
df_clean['Hour'] = df_clean['Timestamp'].dt.hour

df_clean.groupby('Month')[["GHI", "DNI"]].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %%
df_clean.groupby("Cleaning")[["ModA", "ModB"]].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Cleaning'>

# %%
sns.heatmap(df_clean[["GHI", "DNI", "DHI", "TModA", "TModB"]].corr(), annot=True)

sns.scatterplot(data=df_clean, x='WS', y='GHI')
sns.scatterplot(data=df_clean, x='RH', y='Tamb')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %%
# Histogram
df_clean['GHI'].plot(kind='hist', bins=50, alpha=0.6)
df_clean['WS'].plot(kind='hist', bins=50, alpha=0.6)

# Wind Rose requires windrose or polar plot (optional)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.scatterplot(data=df_clean, x='RH', y='Tamb', hue='GHI')
# Out:
# <Axes: xlabel='RH', ylabel='Tamb'>
# c:\Users\rebika\solar-challenge-week1\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\Users\rebika\solar-challenge-week1\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_clean, x='GHI', y='Tamb', size='RH', hue='BP', alpha=0.6)
# Out:
# <Axes: xlabel='GHI', ylabel='Tamb'>
# c:\Users\rebika\solar-challenge-week1\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\Users\rebika\solar-challenge-week1\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
